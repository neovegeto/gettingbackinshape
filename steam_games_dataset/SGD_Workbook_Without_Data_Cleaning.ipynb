# %% [markdown]
# DA-Project for training purposses
# Use of Steam Games Dataset from Kaggle
# https://www.kaggle.com/datasets/fronkongames/steam-games-dataset?resource=download

# %% [markdown]
# Loading the DataSet games.csv from the folder sgd_data with Python

# %%
#Importing the necessary libraries
import pandas as pd             # pandas for data frame
import numpy as np              # numpy for array

import matplotlib.pyplot as plt # for plotting
# Will allow us to embed images in the notebook
# %matplotlib inline
from matplotlib.cbook import _reshape_2D

# Seaborn visualization library
# https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166
import seaborn as sns

# %% [markdown]
# For the SQL - Parts

# %%
#For the SQL - Part
# Import the get_engine function from our sql_functions.
from sql_functions import get_engine #adjust this as necessary to match your sql_functions.py connection methods

# Import get_dataframe from sql_functions.py
from sql_functions import get_dataframe

# create a variable called engine using the get_engine function
engine = get_engine()

# %% [markdown]
# we create empty dataframes

# %%
# create an empty dataframe
df = pd.DataFrame()
games = pd.DataFrame()

# %%
#Loading the DataSet games.csv from the folder sgd_data with Python Pandas
# The games.csv file is in the sgd_data folder
# The file is to large for the Upload to GitHub, so you have to download it from the following link:
# https://www.kaggle.com/datasets/fronkongames/steam-games-dataset?resource=download

games = pd.read_csv('sgd_data/games.csv')

# %%
# Load the CSV file into a DataFrame as a copy
df = games

# %% [markdown]
# We want to see everything

# %%
# Set the option to prevent truncation of column names
pd.set_option('display.max_columns', None)

# Reset the option to its default value
#pd.reset_option('display.max_columns')

# %%
# Display the first few rows of the DataFrame
#print(df.head())
display(df.head())
# Out:
#      AppID                   Name  Release date Estimated owners  Peak CCU  \
# 0    20200       Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370           Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930           Jolt Project  Nov 17, 2021        0 - 20000         0
# 3  1355720               Henosis™  Jul 23, 2020        0 - 20000         0
# 4  1139950  Two Weeks in Painland   Feb 3, 2020        0 - 20000         0
#
#    Required age  Price  DLC count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
# 3             0   5.99          0
# 4             0   0.00          0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
# 3  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# ...

# %%
# Display the information of the dataset
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76987 entries, 0 to 76986
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   AppID                       76987 non-null  int64
#  1   Name                        76985 non-null  object
#  2   Release date                76987 non-null  object
#  3   Estimated owners            76987 non-null  object
#  4   Peak CCU                    76987 non-null  int64
#  5   Required age                76987 non-null  int64
#  6   Price                       76987 non-null  float64
#  7   DLC count                   76987 non-null  int64
#  8   About the game              74070 non-null  object
#  9   Supported languages         76987 non-null  object
#  10  Full audio languages        76987 non-null  object
#  11  Reviews                     9362 non-null   object
#  12  Header image                76987 non-null  object
# ...

# %%
# Create a new DataFrame with column names
column_names_df = pd.DataFrame({'Column Names': df.columns})

# Display the new DataFrame
display(column_names_df)
# Out:
#                   Column Names
# 0                        AppID
# 1                         Name
# 2                 Release date
# 3             Estimated owners
# 4                     Peak CCU
# 5                 Required age
# 6                        Price
# 7                    DLC count
# 8               About the game
# 9          Supported languages
# 10        Full audio languages
# 11                     Reviews
# 12                Header image
# 13                     Website
# 14                 Support url
# 15               Support email
# 16                     Windows
# 17                         Mac
# 18                       Linux
# 19            Metacritic score
# 20              Metacritic url
# 21                  User score
# 22                    Positive
# 23                    Negative
# 24                  Score rank
# 25                Achievements
# 26             Recommendations
# 27                       Notes
# 28    Average playtime forever
# ...

# %%
# Display summary statistics of the numerical columns
#print(df.describe())
display(df.describe())
# Out:
#               AppID       Peak CCU  Required age         Price    DLC count  \
# count  7.698700e+04   76987.000000  76987.000000  76987.000000  76987.00000
# mean   1.269910e+06     139.623716      0.329043      7.194212      0.58341
# std    6.398169e+05    5625.483279      2.311714     11.096411     14.41547
# min    1.000000e+01       0.000000      0.000000      0.000000      0.00000
# 25%    7.335650e+05       0.000000      0.000000      0.990000      0.00000
# 50%    1.247830e+06       0.000000      0.000000      4.990000      0.00000
# 75%    1.794750e+06       1.000000      0.000000      9.990000      0.00000
# max    2.546410e+06  872138.000000     21.000000    999.000000   2366.00000
#
#        Metacritic score    User score      Positive       Negative  \
# count      76987.000000  76987.000000  7.698700e+04   76987.000000
# mean           3.585514      0.041890  1.040556e+03     170.194383
# std           15.924939      1.835066  2.559999e+04    4802.148974
# ...

# %%
#Shape of the DataFrame
display(df.shape)
# Out:
# (76987, 39)

# %%
# Data Types
display(df.dtypes)
# Out:
# AppID                           int64
# Name                           object
# Release date                   object
# Estimated owners               object
# Peak CCU                        int64
# Required age                    int64
# Price                         float64
# DLC count                       int64
# About the game                 object
# Supported languages            object
# Full audio languages           object
# Reviews                        object
# Header image                   object
# Website                        object
# Support url                    object
# Support email                  object
# Windows                          bool
# Mac                              bool
# Linux                            bool
# Metacritic score                int64
# Metacritic url                 object
# User score                      int64
# Positive                        int64
# Negative                        int64
# Score rank                    float64
# ...

# %%
# Check for missing values
display(df.isnull().sum())
# Out:
# AppID                             0
# Name                              2
# Release date                      0
# Estimated owners                  0
# Peak CCU                          0
# Required age                      0
# Price                             0
# DLC count                         0
# About the game                 2917
# Supported languages               0
# Full audio languages              0
# Reviews                       67625
# Header image                      0
# Website                       40308
# Support url                   38759
# Support email                 12090
# Windows                           0
# Mac                               0
# Linux                             0
# Metacritic score                  0
# Metacritic url                73195
# User score                        0
# Positive                          0
# Negative                          0
# Score rank                    76945
# Achievements                      0
# ...

# %%
#Correlation Matrix:

# To compute the correlation matrix for numerical columns:
correlation_matrix = df.corr()
display(correlation_matrix)
# Out:
#                                AppID  Peak CCU  Required age     Price  \
# AppID                       1.000000 -0.014522     -0.101116 -0.087071
# Peak CCU                   -0.014522  1.000000      0.034502  0.042383
# Required age               -0.101116  0.034502      1.000000  0.109038
# Price                      -0.087071  0.042383      0.109038  1.000000
# DLC count                  -0.029946  0.009273      0.014980  0.049003
# Windows                     0.006843  0.000465     -0.007837 -0.022591
# Mac                        -0.212767  0.007816     -0.005129  0.027239
# Linux                      -0.157372  0.009135     -0.000224  0.015230
# Metacritic score           -0.284167  0.059180      0.198124  0.166084
# User score                 -0.016034 -0.000549      0.084296 -0.000111
# Positive                   -0.050402  0.647506      0.068496  0.033565
# Negative                   -0.040323  0.590100      0.064144  0.027661
# ...

# %%
# Create the Heatmap:
# Use the seaborn library to create a heatmap from the correlation matrix. 
# You can customize the appearance of the heatmap using various parameters:
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# Set the style of the heatmap
sns.set(style="white")

# Create a heatmap using the correlation matrix
plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Select only the numeric columns for plotting histograms
numeric_columns = df.select_dtypes(include=['number'])

# Set the figure size for the histograms
plt.figure(figsize=(12, 8))  # Adjust the figure size if needed

# Plot histograms for numeric columns
for column in numeric_columns.columns:
    plt.hist(numeric_columns[column], bins=20, alpha=0.7, label=column)

# Add labels, legend, and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histograms for Numeric Columns')
plt.legend()

# Display the histograms
plt.show()

# %%
# Select only the numeric columns for plotting histograms
numeric_columns = df.select_dtypes(include=['number'])

# Set the figure size
plt.figure(figsize=(12, 8))

# Create histograms for each numeric column
for column in numeric_columns.columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df[column], bins=20)  # Remove the alpha parameter
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram for {column}')
    plt.show()

# %%
# Set the Seaborn style (optional)
sns.set(style="whitegrid")

# Filter out non-numeric columns
numeric_columns = df.select_dtypes(include=['number'])

# Create box plots for each numeric column
for column in numeric_columns.columns:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=df[column])
    plt.xlabel('Column')
    plt.ylabel('Value')
    plt.title(f'Box Plot for Column: {column}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Select numeric columns for density plots
numeric_columns = df.select_dtypes(include=['number'])

# Set the Seaborn style
sns.set(style="whitegrid")

# Create density plots for selected numeric columns
for column in numeric_columns.columns:
    plt.figure(figsize=(8, 6))
    sns.kdeplot(df[column], shade=True)  # Create density plot
    plt.xlabel(column)
    plt.ylabel('Density')
    plt.title(f'Density Plot for {column}')
    plt.show()

# %%
# Select numeric columns for scatter plots
numeric_columns = df.select_dtypes(include=['number'])

# Set the figure size
plt.figure(figsize=(10, 8))

# Create scatter plots for selected pairs of numeric columns
scatter_pairs = [
    ('Peak CCU', 'Metacritic score'),
    ('User score', 'Positive'),
    ('User score', 'Negative'),
    ('Average playtime forever', 'Median playtime forever')
]

for x_column, y_column in scatter_pairs:
    plt.figure(figsize=(8, 6))
    plt.scatter(df[x_column], df[y_column], alpha=0.5)
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title(f'Scatter Plot: {x_column} vs. {y_column}')
    plt.grid(True)
    plt.show()

# %%
# Convert 'Release date' column to datetime
df['Release date'] = pd.to_datetime(df['Release date'])

# Create a time series plot for release dates
plt.figure(figsize=(12, 8))
plt.plot(df['Release date'], marker='o')
plt.ylabel('Release Date')
plt.xlabel('Count')
plt.title('Game Releases Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Create a histogram for estimated owners
plt.figure(figsize=(12, 8))
plt.hist(df['Estimated owners'], bins=20, alpha=0.7)
plt.xlabel('Estimated Owners')
plt.ylabel('Frequency')
plt.title('Distribution of Estimated Owners')
plt.tight_layout()
plt.show()

# %%
# Sort the DataFrame by 'Price' column in descending order
df_sorted = df.sort_values(by='Price', ascending=False)

# Get the game with the highest price
highest_price_game = df_sorted.iloc[0]

print("Game with the highest price:")
display(highest_price_game)
# Out:
# Game with the highest price:
# AppID                                                                   1200520
# Name                                          Ascent Free-Roaming VR Experience
# Release date                                                2019-12-27 00:00:00
# Estimated owners                                                      0 - 20000
# Peak CCU                                                                      0
# Required age                                                                  0
# Price                                                                     999.0
# DLC count                                                                     0
# About the game                The Ascent is a Free-Roaming highly immersive ...
# Supported languages                                                 ['English']
# Full audio languages                                                ['English']
# ...

# %% [markdown]
# # As you can see, not everything is working with the graphics and not everything is maybe usefull for further analysis. Maybe we should so some DataCleaning
